# %% [markdown]
# <a href="https://colab.research.google.com/github/4362725Gb/ml-zoomcamp-homework/blob/main/08-deep-learning/08_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://github.com/SVizor42/ML_Zoomcamp/releases/download/straight-curly-data/data.zip
# !unzip data.zip

# %%
ls -l
# Out:
# total 8
# drwx------ 2 root root 4096 Dec  1 08:03 clothing-dataset-small/
# drwx------ 2 root root 4096 Dec  1 13:23 hair_data/

# %%
cd zoomcamp2024/
# Out:
# /content/drive/MyDrive/zoomcamp2024

# %%
import numpy as np
import tensorflow as tf

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
tf.__version__
# Out:
# '2.17.1'

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.applications.xception import decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Loading sample image

# %%
path = '/content/drive/MyDrive/zoomcamp2024/hair_data/train/curly/'
name = '0160dfee18352aa9bf5c6e617de9e07b4.jpg'
fullname = f'{path}/{name}'
img = load_img(fullname , target_size=(299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %% [markdown]
# Define training variable

# %%
x = np.array(img)
X = np.array([x])
X.shape
# Out:
# (1, 299, 299, 3)
